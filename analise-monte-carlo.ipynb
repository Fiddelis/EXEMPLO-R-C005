# %% [markdown]
# R Code pulled from https://www.statmethods.net/advgraphs/ggplot2.html

# %%
#Projeto Apresentação - C005

# %%
#Calculando PI com Monte Carlo

# %% [markdown]
# <img src= https://www.basic-mathematics.com/images/equation-of-a-circle.jpg>

# %%
n_sim <- 10000

x <- runif(n_sim,min=-0.5,max=0.5)
y <- runif(n_sim,min=-0.5,max=0.5)

dentro_circulo <- x^2 + y^2 <= 0.5^2

pi_monte_carlo <- (sum(dentro_circulo)/n_sim)*4

plot(x,y,pch='.',col=ifelse(dentro_circulo,"blue","grey")
     ,xlab='',ylab='',asp=1,
     main=paste("Aproximacao de PI com Monte Carlo:",pi_monte_carlo))
# Out:
# Plot with title “Aproximacao de PI com Monte Carlo: 3.1316”
